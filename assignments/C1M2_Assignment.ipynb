# %% [markdown]
# ## Graded Lab: Reflection in a Research Agent
#
# In this graded lab, you’ll implement a simple **agentic workflow** designed to simulate reflective thinking in a writing task. This is one building block of a more complex research agent that will be constructed throughout the course.
#
# ### Objective
#
# Build a three-step workflow where an LLM writes an essay draft, critiques it, and rewrites it.
#
# * **Step 1 – Drafting:** Call the LLM to generate an initial draft of an essay based on a simple prompt.
# * **Step 2 – Reflection:** Reflect on the draft using a reasoning step. (Optionally, this can be done with a different model.)
# * **Step 3 – Revision:** Apply the feedback from the reflection to generate a revised version of the essay.

# %% [markdown]
# ---
# <a name='submission'></a>
#
# <h4 style="color:green; font-weight:bold;">TIPS FOR SUCCESSFUL GRADING OF YOUR ASSIGNMENT:</h4>
#
# * All cells are frozen except for the ones where you need to write your solution code or when explicitly mentioned you can interact with it.
#
# * In each exercise cell, look for comments `### START CODE HERE ###` and `### END CODE HERE ###`. These show you where to write the solution code. **Do not add or change any code that is outside these comments**.
#
# * You can add new cells to experiment but these will be omitted by the grader, so don't rely on newly created cells to host your solution code, use the provided places for this.
#
# * Avoid using global variables unless you absolutely have to. The grader tests your code in an isolated environment without running all cells from the top. As a result, global variables may be unavailable when scoring your submission. Global variables that are meant to be used will be defined in UPPERCASE.
#
# * To submit your notebook for grading, first save it by clicking the 💾 icon on the top left of the page and then click on the <span style="background-color: red; color: white; padding: 3px 5px; font-size: 16px; border-radius: 5px;">Submit assignment</span> button on the top right of the page.
# ---

# %% [markdown]
# Before interacting with the language models, we initialize the `aisuite` client. This setup loads environment variables (e.g., API keys) from a `.env` file to securely authenticate with backend services. The `ai.Client()` instance will be used to make all model calls throughout this workflow.

# %%
from dotenv import load_dotenv

load_dotenv()

import aisuite as ai

# Define the client. You can use this variable inside your graded functions!
CLIENT = ai.Client()

# %%
import unittests

# %% [markdown]
# ## Exercise 1: `generate_draft` Function
#
# **Objective**:
# Write a function called `generate_draft` that takes in a string topic and uses a language model to generate a complete draft essay.
#
# **Inputs**:
#
# * `topic` (str): The essay topic.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string representing the full draft of the essay.
#
# The setup for calling the LLM using the aisuite library is already provided. Focus on crafting the prompt content. You can reference this setup in later exercises to understand how to interact with the library effectively.

# %%
# GRADED FUNCTION: generate_draft

def generate_draft(topic: str, model: str = "openai:gpt-4o") -> str: 
    
    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an essay assistant. 
    Given the topic, write an essay for this topic.
    
    The topic is {topic}
    """ 

    ### END CODE HERE ###
    
    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %% [markdown]
# Run the following cell to check your code is working correctly:

# %%
# Test your code!
unittests.test_generate_draft(generate_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 2: `reflect_on_draft` Function
#
# **Objective**:
# Write a function called `reflect_on_draft` that takes a previously generated essay draft and uses a language model to provide constructive feedback.
#
# **Inputs**:
#
# * `draft` (str): The essay text to reflect on.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:o4-mini"`.
#
# **Output**:
#
# * A string with feedback in paragraph form.
#
# **Requirements**:
#
# * The feedback should be critical but constructive.
# * It should address issues such as structure, clarity, strength of argument, and writing style.
# * The function should send the draft to the model and return its response.
#
# You do **not** need to rewrite the essay at this step—just analyze and reflect on it.

# %%
# GRADED FUNCTION: reflect_on_draft

def reflect_on_draft(draft: str, model: str = "openai:o4-mini") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an essay reviewer and refiner.

    Original draft:
    {draft}
    
    Step 1: Briefly evaluate if the essay.
    Step 2: If improvement is needed, please generation reflection on the draft.
    """  

    ### END CODE HERE ###

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=1.0,
    )

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_reflect_on_draft(reflect_on_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ## Exercise 3: `revise_draft` Function
#
# **Objective**:
# Implement a function called `revise_draft` that improves a given essay draft based on feedback from a reflection step.
#
# **Inputs**:
#
# * `original_draft` (str): The initial version of the essay.
# * `reflection` (str): Constructive feedback or critique on the draft.
# * `model` (str, optional): The model identifier to use. Defaults to `"openai:gpt-4o"`.
#
# **Output**:
#
# * A string containing the revised and improved essay.
#
# **Requirements**:
#
# * The revised draft should address the issues mentioned in the feedback.
# * It should improve clarity, coherence, argument strength, and overall flow.
# * The function should use the feedback to guide the revision, and return only the final revised essay.
#
# In this final exercise, you'll also need to manage the call to the LLM using the CLIENT, as you've practiced in previous exercises.

# %%
# GRADED FUNCTION: revise_draft

def revise_draft(original_draft: str, reflection: str, model: str = "openai:gpt-4o") -> str:

    ### START CODE HERE ###

    # Define your prompt here. A multi-line f-string is typically used for this.
    prompt = f"""
    You are an essay reviewer and refiner by reflection.

    Original draft:
    {original_draft}
    
    Reflection:
    {reflection}
    
    Step 1: Briefly evaluate if the essay
    Step 2: If improvement is needed, by reflection. Rewrite the essay.
    """ 

    # Get a response from the LLM by creating a chat with the client.
    response = CLIENT.chat.completions.create(
        model=model,
        messages=[{"role": "user", "content": prompt}],
        temperature=0,
    )

    ### END CODE HERE ###

    return response.choices[0].message.content

# %%
# Test your code!
unittests.test_revise_draft(revise_draft)
# Out:
#  All tests passed!

# %% [markdown]
# ### 🧪 Test the Reflective Writing Workflow
#
# Use the functions you implemented to simulate the complete writing workflow:
#
# 1. **Generate a draft** in response to the essay prompt.
# 2. **Reflect** on the draft to identify improvements.
# 3. **Revise** the draft using the feedback.
#
# Observe the outputs of each step. You do **not** need to modify the outputs — just verify that the workflow runs as expected and each component returns a valid string.

# %%
essay_prompt = "Should social media platforms be regulated by the government?"

# Agent 1 – Draft
draft = generate_draft(essay_prompt)
print("📝 Draft:\n")
print(draft)

# Agent 2 – Reflection
feedback = reflect_on_draft(draft)
print("\n🧠 Feedback:\n")
print(feedback)

# Agent 3 – Revision
revised = revise_draft(draft, feedback)
print("\n✍️ Revised:\n")
print(revised)
# Out:
# 📝 Draft:
#
# Title: The Case for Government Regulation of Social Media Platforms
#
# In the digital age, social media platforms have become an integral component of daily life for billions across the globe. They serve as conduits for communication, sources of news, and frameworks for social engagement. However, with great influence comes great responsibility, and indeed, numerous challenges have arisen accompanying the explosive growth of these platforms. Among these challenges are issues of privacy, misinformation, cyberbullying, and political manipulation. Consequently, the question arises: Should social media platforms be regulated by the government? This essay argues for the regulation of social media platforms by government entities, though with caution, aiming to protect individual rights, preserve democratic processes, and maintain societal harmony.
#
# Firstly, the regulation of social media platforms is essential for protecting individual privacy rights. With vast amounts of personal data collected by these platforms, users’ privacy has become increasingly vulnerable. Revelations of data breaches and misuse, such as the Cambridge Analytica scandal involving Facebook, underscore the potential for abuse. When personal data is compromised, it not only threatens individual privacy but also poses broader societal risks, including identity theft and unauthorized tracking. Government regulation can mandate strict data protection laws ensuring that social media companies prioritize user privacy and are accountable for any mishandling of personal information. Such a regulatory framework would standardize security measures, offering users a safer digital environment.
#
# Additionally, government intervention is crucial in combating misinformation, which has increasingly plagued social media platforms. Misinformation and fake news can spread rapidly across the digital landscape, often with significant real-world consequences. During critical moments like election cycles or public health crises, as seen during the COVID-19 pandemic, misinformation can alter perceptions and decisions to detrimental effect. In the absence of effective regulation, social media companies may lack the incentive or capacity to adequately address these issues on their own. Government regulations could compel platforms to implement rigorous fact-checking protocols, and transparency measures, and establish mechanisms for users to report and rectify false information promptly.
#
# Moreover, the regulation of social media platforms is necessary for safeguarding democratic processes. The manipulation of social media to influence political outcomes has been demonstrated in numerous instances, most notably in allegations of foreign interference in elections. Bots, trolls, and algorithm-driven echo chambers can distort political discourse and exacerbate polarization among voters. Through regulation, governments can work to ensure transparency in political advertising, require the disclosure of information sources, and enforce rules that prevent the dissemination of manipulative content aimed at subverting democratic processes. In doing so, they can foster a healthier, more informed, and engaged citizenry.
#
# However, it is imperative that government regulation be implemented with caution to avoid potential pitfalls. An overreach could lead to censorship or the stifling of free expression, fundamentally infringing upon the very liberties the regulations seek to protect. Therefore, any regulatory measures should be carefully crafted, with input from stakeholders including technology experts, civil society organizations, and the public. The objective should be to create balanced policies that empower users, hold platforms accountable, and preserve the foundational principles of free speech and open dialogue.
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, their unchecked growth presents significant challenges that warrant government regulation. Protecting privacy, combating misinformation, and preserving democratic integrity are pivotal responsibilities that governments must assume in this digital era. However, regulation must be approached judiciously to ensure that it enhances, rather than undermines, the values of open and democratic discourse. Through thoughtful and measured intervention, societies can harness the benefits of social media while mitigating its inherent risks.
#
# 🧠 Feedback:
#
# Step 1: Evaluation
# The draft is clear, well‐organized, and presents a balanced case for government regulation of social media. It has a concise thesis, three focused body paragraphs (privacy, misinformation, democratic integrity), and a cautionary note on free speech. It effectively uses the Cambridge Analytica and COVID-19 examples to illustrate real‐world stakes.
#
# Step 2: Reflection & Suggestions for Improvement
# 1. Strengthen the Hook and Context
#   • Open with a vivid statistic or anecdote (e.g., daily user numbers, a high-profile data breach) to grab attention.
#   • Briefly acknowledge opposing views up front (e.g., “Critics warn that regulation may stifle innovation…”).
#
# 2. Bolster Evidence and Depth
#   • Cite additional studies or reports (e.g., specific data-breach fines, fact-checking success rates).
#   • Compare different regulatory models (EU’s GDPR vs. U.S. self-regulation) to show what works.
#
# 3. Develop Counterarguments
#   • Introduce a short paragraph addressing fears of government overreach or censorship.
#   • Refute these concerns with examples of narrowly tailored laws or oversight bodies.
#
# 4. Refine Policy Proposals
#   • Move from general calls (“mandate strict data-protection laws”) to specific measures (e.g., “require platforms to obtain user consent for each data use,” “establish an independent oversight board”).
#   • Suggest enforcement mechanisms and penalties for noncompliance.
#
# 5. Vary Language and Tone
#   • Reduce repetition of “social media platforms” by using synonyms (e.g., “networks,” “sites,” “services”).
#   • Replace clichés (“with great influence comes great responsibility”) with fresh phrasing.
#
# 6. Improve Transitions and Flow
#   • Use bridging sentences between paragraphs (e.g., “Having considered privacy, we now turn to the public health costs of unchecked misinformation.”).
#   • Ensure each paragraph ends by tying back to the thesis.
#
# 7. Sharpen the Conclusion
#   • Revisit the opening anecdote or statistic to create a “full-circle” effect.
#   • Offer a forward-looking statement (e.g., “As legislators draft new rules, public engagement will remain key to safeguarding both security and speech.”).
#
# By adding concrete data, engaging counterarguments, and precise policy recommendations—while tightening style and flow—you can elevate this solid draft into a more compelling, authoritative essay.
#
# ✍️ Revised:
#
# **Step 1: Evaluation**
#
# The original draft is well-structured and presents a coherent argument for the regulation of social media platforms by government entities. It effectively outlines the key issues of privacy, misinformation, and democratic integrity, while also acknowledging the need for caution to avoid infringing on free speech. However, the essay could benefit from a stronger introduction, more detailed evidence, and a more nuanced exploration of counterarguments. Additionally, the policy proposals could be more specific, and the language could be varied to maintain reader engagement.
#
# **Step 2: Reflection & Suggestions for Improvement**
#
# **Rewritten Essay:**
#
# **Title: Navigating the Digital Frontier: The Imperative for Government Regulation of Social Media**
#
# In today's digital landscape, social media platforms have woven themselves into the fabric of daily life for billions worldwide. With over 4.5 billion active users globally, these platforms are not just tools for communication but also powerful influencers of public opinion and behavior. However, this immense influence brings with it significant responsibilities and challenges, including privacy violations, the spread of misinformation, and political manipulation. Critics argue that government regulation could stifle innovation and free expression, yet the potential risks of inaction are too great to ignore. This essay advocates for thoughtful government regulation of social media platforms to protect individual rights, uphold democratic processes, and maintain societal harmony.
#
# To begin with, safeguarding individual privacy rights is a critical reason for regulating social media platforms. The vast troves of personal data collected by these networks make users vulnerable to breaches and misuse, as evidenced by the infamous Cambridge Analytica scandal involving Facebook. Such incidents highlight the potential for abuse, threatening not only individual privacy but also societal security through risks like identity theft and unauthorized surveillance. Government regulation can enforce stringent data protection laws, such as requiring explicit user consent for each data use and establishing independent oversight boards to ensure compliance. By standardizing security measures, these regulations would create a safer digital environment for all users.
#
# Furthermore, government intervention is essential in addressing the rampant spread of misinformation on social media. False information can travel rapidly across these platforms, often with dire real-world consequences. For instance, during the COVID-19 pandemic, misinformation about the virus and vaccines led to widespread confusion and hesitancy. Without effective regulation, social media companies may lack the incentive or capability to tackle these issues adequately. Government regulations could mandate rigorous fact-checking protocols, transparency measures, and user-friendly mechanisms for reporting and correcting false information. Comparing regulatory models, such as the European Union's General Data Protection Regulation (GDPR) versus the U.S.'s more laissez-faire approach, can provide insights into effective strategies.
#
# Moreover, regulating social media is crucial for protecting democratic processes. The manipulation of these platforms to influence political outcomes has been well-documented, with allegations of foreign interference in elections being a prime example. Bots, trolls, and algorithm-driven echo chambers can distort political discourse and deepen societal polarization. Through regulation, governments can ensure transparency in political advertising, require the disclosure of information sources, and enforce rules to prevent the spread of manipulative content. These measures would foster a more informed and engaged citizenry, strengthening the democratic fabric.
#
# However, it is vital that government regulation be implemented with caution to avoid potential pitfalls such as censorship or the stifling of free expression. Regulatory measures should be carefully crafted with input from technology experts, civil society organizations, and the public. The goal should be to create balanced policies that empower users, hold platforms accountable, and preserve the foundational principles of free speech and open dialogue. Examples of narrowly tailored laws and oversight bodies can help alleviate concerns about government overreach.
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, their unchecked growth presents significant challenges that necessitate government regulation. Protecting privacy, combating misinformation, and preserving democratic integrity are pivotal responsibilities that governments must assume in this digital era. However, regulation must be approached judiciously to ensure that it enhances, rather than undermines, the values of open and democratic discourse. As legislators draft new rules, public engagement will remain key to safeguarding both security and speech. Through thoughtful and measured intervention, societies can harness the benefits of social media while mitigating its inherent risks.

# %% [markdown]
# To better visualize the output of each step in the reflective writing workflow, we use a utility function called `show_output`. This function displays the results of each stage (drafting, reflection, and revision) in styled boxes with custom background and text colors, making it easier to compare and understand the progression of the essay.

# %%
from utils import show_output

essay_prompt = "Should social media platforms be regulated by the government?"

show_output("Step 1 – Draft", draft, background="#fff8dc", text_color="#333333")
show_output("Step 2 – Reflection", feedback, background="#e0f7fa", text_color="#222222")
show_output("Step 3 – Revision", revised, background="#f3e5f5", text_color="#222222")
# Out:
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #fff8dc;
#         color: #333333;
#     ">
#         <h3 style="margin-top: 0;">Step 1 – Draft</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Title: The Case for Government Regulation of Social Media Platforms
#
# In the digital age, social media platforms have become an integral component of daily life for billions across the globe. They serve as conduits for communication, sources of news, and frameworks for social engagement. However, with great influence comes great responsibility, and indeed, numerous challenges have arisen accompanying the explosive growth of these platforms. Among these challenges are issues of privacy, misinformation, cyberbullying, and political manipulation. Consequently, the question arises: Should social media platforms be regulated by the government? This essay argues for the regulation of social media platforms by government entities, though with caution, aiming to protect individual rights, preserve democratic processes, and maintain societal harmony.
#
# Firstly, the regulation of social media platforms is essential for protecting individual privacy rights. With vast amounts of personal data collected by these platforms, users’ privacy has become increasingly vulnerable. Revelations of data breaches and misuse, such as the Cambridge Analytica scandal involving Facebook, underscore the potential for abuse. When personal data is compromised, it not only threatens individual privacy but also poses broader societal risks, including identity theft and unauthorized tracking. Government regulation can mandate strict data protection laws ensuring that social media companies prioritize user privacy and are accountable for any mishandling of personal information. Such a regulatory framework would standardize security measures, offering users a safer digital environment.
#
# Additionally, government intervention is crucial in combating misinformation, which has increasingly plagued social media platforms. Misinformation and fake news can spread rapidly across the digital landscape, often with significant real-world consequences. During critical moments like election cycles or public health crises, as seen during the COVID-19 pandemic, misinformation can alter perceptions and decisions to detrimental effect. In the absence of effective regulation, social media companies may lack the incentive or capacity to adequately address these issues on their own. Government regulations could compel platforms to implement rigorous fact-checking protocols, and transparency measures, and establish mechanisms for users to report and rectify false information promptly.
#
# Moreover, the regulation of social media platforms is necessary for safeguarding democratic processes. The manipulation of social media to influence political outcomes has been demonstrated in numerous instances, most notably in allegations of foreign interference in elections. Bots, trolls, and algorithm-driven echo chambers can distort political discourse and exacerbate polarization among voters. Through regulation, governments can work to ensure transparency in political advertising, require the disclosure of information sources, and enforce rules that prevent the dissemination of manipulative content aimed at subverting democratic processes. In doing so, they can foster a healthier, more informed, and engaged citizenry.
#
# However, it is imperative that government regulation be implemented with caution to avoid potential pitfalls. An overreach could lead to censorship or the stifling of free expression, fundamentally infringing upon the very liberties the regulations seek to protect. Therefore, any regulatory measures should be carefully crafted, with input from stakeholders including technology experts, civil society organizations, and the public. The objective should be to create balanced policies that empower users, hold platforms accountable, and preserve the foundational principles of free speech and open dialogue.
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, their unchecked growth presents significant challenges that warrant government regulation. Protecting privacy, combating misinformation, and preserving democratic integrity are pivotal responsibilities that governments must assume in this digital era. However, regulation must be approached judiciously to ensure that it enhances, rather than undermines, the values of open and democratic discourse. Through thoughtful and measured intervention, societies can harness the benefits of social media while mitigating its inherent risks.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #e0f7fa;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 2 – Reflection</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">Step 1: Evaluation
# The draft is clear, well‐organized, and presents a balanced case for government regulation of social media. It has a concise thesis, three focused body paragraphs (privacy, misinformation, democratic integrity), and a cautionary note on free speech. It effectively uses the Cambridge Analytica and COVID-19 examples to illustrate real‐world stakes.
#
# Step 2: Reflection & Suggestions for Improvement
# 1. Strengthen the Hook and Context
#   • Open with a vivid statistic or anecdote (e.g., daily user numbers, a high-profile data breach) to grab attention.
#   • Briefly acknowledge opposing views up front (e.g., “Critics warn that regulation may stifle innovation…”).
#
# 2. Bolster Evidence and Depth
#   • Cite additional studies or reports (e.g., specific data-breach fines, fact-checking success rates).
#   • Compare different regulatory models (EU’s GDPR vs. U.S. self-regulation) to show what works.
#
# 3. Develop Counterarguments
#   • Introduce a short paragraph addressing fears of government overreach or censorship.
#   • Refute these concerns with examples of narrowly tailored laws or oversight bodies.
#
# 4. Refine Policy Proposals
#   • Move from general calls (“mandate strict data-protection laws”) to specific measures (e.g., “require platforms to obtain user consent for each data use,” “establish an independent oversight board”).
#   • Suggest enforcement mechanisms and penalties for noncompliance.
#
# 5. Vary Language and Tone
#   • Reduce repetition of “social media platforms” by using synonyms (e.g., “networks,” “sites,” “services”).
#   • Replace clichés (“with great influence comes great responsibility”) with fresh phrasing.
#
# 6. Improve Transitions and Flow
#   • Use bridging sentences between paragraphs (e.g., “Having considered privacy, we now turn to the public health costs of unchecked misinformation.”).
#   • Ensure each paragraph ends by tying back to the thesis.
#
# 7. Sharpen the Conclusion
#   • Revisit the opening anecdote or statistic to create a “full-circle” effect.
#   • Offer a forward-looking statement (e.g., “As legislators draft new rules, public engagement will remain key to safeguarding both security and speech.”).
#
# By adding concrete data, engaging counterarguments, and precise policy recommendations—while tightening style and flow—you can elevate this solid draft into a more compelling, authoritative essay.</pre>
#     </div>
#     <div style="
#         border: 1px solid #ccc;
#         border-radius: 10px;
#         padding: 15px;
#         margin-bottom: 15px;
#         background-color: #f3e5f5;
#         color: #222222;
#     ">
#         <h3 style="margin-top: 0;">Step 3 – Revision</h3>
#         <pre style="
#             white-space: pre-wrap;
#             font-family: monospace;
#             font-size: 14px;
#         ">**Step 1: Evaluation**
#
# The original draft is well-structured and presents a coherent argument for the regulation of social media platforms by government entities. It effectively outlines the key issues of privacy, misinformation, and democratic integrity, while also acknowledging the need for caution to avoid infringing on free speech. However, the essay could benefit from a stronger introduction, more detailed evidence, and a more nuanced exploration of counterarguments. Additionally, the policy proposals could be more specific, and the language could be varied to maintain reader engagement.
#
# **Step 2: Reflection & Suggestions for Improvement**
#
# **Rewritten Essay:**
#
# **Title: Navigating the Digital Frontier: The Imperative for Government Regulation of Social Media**
#
# In today's digital landscape, social media platforms have woven themselves into the fabric of daily life for billions worldwide. With over 4.5 billion active users globally, these platforms are not just tools for communication but also powerful influencers of public opinion and behavior. However, this immense influence brings with it significant responsibilities and challenges, including privacy violations, the spread of misinformation, and political manipulation. Critics argue that government regulation could stifle innovation and free expression, yet the potential risks of inaction are too great to ignore. This essay advocates for thoughtful government regulation of social media platforms to protect individual rights, uphold democratic processes, and maintain societal harmony.
#
# To begin with, safeguarding individual privacy rights is a critical reason for regulating social media platforms. The vast troves of personal data collected by these networks make users vulnerable to breaches and misuse, as evidenced by the infamous Cambridge Analytica scandal involving Facebook. Such incidents highlight the potential for abuse, threatening not only individual privacy but also societal security through risks like identity theft and unauthorized surveillance. Government regulation can enforce stringent data protection laws, such as requiring explicit user consent for each data use and establishing independent oversight boards to ensure compliance. By standardizing security measures, these regulations would create a safer digital environment for all users.
#
# Furthermore, government intervention is essential in addressing the rampant spread of misinformation on social media. False information can travel rapidly across these platforms, often with dire real-world consequences. For instance, during the COVID-19 pandemic, misinformation about the virus and vaccines led to widespread confusion and hesitancy. Without effective regulation, social media companies may lack the incentive or capability to tackle these issues adequately. Government regulations could mandate rigorous fact-checking protocols, transparency measures, and user-friendly mechanisms for reporting and correcting false information. Comparing regulatory models, such as the European Union's General Data Protection Regulation (GDPR) versus the U.S.'s more laissez-faire approach, can provide insights into effective strategies.
#
# Moreover, regulating social media is crucial for protecting democratic processes. The manipulation of these platforms to influence political outcomes has been well-documented, with allegations of foreign interference in elections being a prime example. Bots, trolls, and algorithm-driven echo chambers can distort political discourse and deepen societal polarization. Through regulation, governments can ensure transparency in political advertising, require the disclosure of information sources, and enforce rules to prevent the spread of manipulative content. These measures would foster a more informed and engaged citizenry, strengthening the democratic fabric.
#
# However, it is vital that government regulation be implemented with caution to avoid potential pitfalls such as censorship or the stifling of free expression. Regulatory measures should be carefully crafted with input from technology experts, civil society organizations, and the public. The goal should be to create balanced policies that empower users, hold platforms accountable, and preserve the foundational principles of free speech and open dialogue. Examples of narrowly tailored laws and oversight bodies can help alleviate concerns about government overreach.
#
# In conclusion, while social media platforms have revolutionized communication and connectivity, their unchecked growth presents significant challenges that necessitate government regulation. Protecting privacy, combating misinformation, and preserving democratic integrity are pivotal responsibilities that governments must assume in this digital era. However, regulation must be approached judiciously to ensure that it enhances, rather than undermines, the values of open and democratic discourse. As legislators draft new rules, public engagement will remain key to safeguarding both security and speech. Through thoughtful and measured intervention, societies can harness the benefits of social media while mitigating its inherent risks.</pre>
#     </div>

# %% [markdown]
# ## Check grading feedback
#
# If you have collapsed the right panel to have more screen space for your code, as shown below:
#
# <img src="./images/collapsed.png" alt="Collapsed Image" width="800" height="400"/>
#
# You can click on the left-facing arrow button (highlighted in red) to view feedback for your submission after submitting it for grading. Once expanded, it should display like this:
#
# <img src="./images/expanded.png" alt="Expanded Image" width="800" height="400"/>
